# %% [markdown]
# ### Section 2: Multi Armed Bandits

# %% [markdown]
# #### 6.0 Thompson Sampling

# %% [markdown]
# #### 5.0 - UCB1 Theory

# %%
from __future__ import print_function, division
from builtins import range
import numpy as np
import matplotlib.pyplot as plt


NUM_TRIALS = 100000
EPS = 0.1
BANDIT_PROBABILITIES = [0.2, 0.5, 0.75]


class Bandit:
    def __init__(self, p):
        # p: the win rate
        self.p = p
        self.p_estimate = 0.
        self.N = 0. # num samples collected so far
  
    def pull(self):
        # draw a 1 with probability p
        return np.random.random() < self.p
  
    def update(self, x):
        self.N += 1.
        self.p_estimate = ((self.N - 1)*self.p_estimate + x) / self.N


def ucb(mean, n, nj):
    # Return the value that we want to be greedy with respect to
    return mean + np.sqrt(2*np.log(n)/nj) # TODO


def run_experiment():
    bandits = [Bandit(p) for p in BANDIT_PROBABILITIES]
    rewards = np.empty(NUM_TRIALS)
    total_plays = 0
  
    # initialization: play each bandit once
    for j in range(len(bandits)):
        x = bandits[j].pull()
        total_plays += 1
        bandits[j].update(x)
    
    for i in range(NUM_TRIALS):
        j = np.argmax([ucb(b.p_estimate, total_plays, b.N) for b in bandits]) # TODO
        x = bandits[j].pull()
        total_plays += 1
        bandits[j].update(x)
    
        # for the plot
        rewards[i] = x
    cumulative_average = np.cumsum(rewards) / (np.arange(NUM_TRIALS) + 1)
  
    # plot moving average ctr
    plt.plot(cumulative_average)
    plt.plot(np.ones(NUM_TRIALS)*np.max(BANDIT_PROBABILITIES))
    plt.xscale('log')
    plt.show()
  
    # plot moving average ctr linear
    plt.plot(cumulative_average)
    plt.plot(np.ones(NUM_TRIALS)*np.max(BANDIT_PROBABILITIES))
    plt.show()
  
    for b in bandits:
        print(b.p_estimate)
  
    print("total reward earned:", rewards.sum())
    print("overall win rate:", rewards.sum() / NUM_TRIALS)
    print("num times selected each bandit:", [b.N for b in bandits])
  
    return cumulative_average

if __name__ == '__main__':
    run_experiment()
# Out:
# 0.20270270270270271
# 0.5135135135135125
# 0.7478781426089092
# total reward earned: 74661.0
# overall win rate: 0.74661
# num times selected each bandit: [74.0, 370.0, 99559.0]

# %% [markdown]
# #### 4.0 - optimistic initial value

# %%
from __future__ import print_function, division
from builtins import range
import matplotlib.pyplot as plt
import numpy as np


NUM_TRIALS = 10000
EPS = 0.1
BANDIT_PROBABILITIES = [0.2, 0.5, 0.75]


class Bandit:
    def __init__(self, p):
        # p: the win rate
        self.p = p
        self.p_estimate = 5# TODO
        self.N = 1 # TODO

    def pull(self):
        # draw a 1 with probability p
        return np.random.random() < self.p

    def update(self, x):
        # TODO
        self.N += 1
        self.p_estimate = (1 - 1.0/self.N)*self.p_estimate + 1.0/self.N*x # TODO

def experiment():
    bandits = [Bandit(p) for p in BANDIT_PROBABILITIES]

    rewards = np.zeros(NUM_TRIALS)
    for i in range(NUM_TRIALS):
      # use optimistic initial values to select the next bandit
      j = np.argmax([b.p_estimate for b in bandits]) # TODO

      # pull the arm for the bandit with the largest sample
      x = bandits[j].pull()

      # update rewards log
      rewards[i] = x

      # update the distribution for the bandit whose arm we just pulled
      bandits[j].update(x)


    # print mean estimates for each bandit
    for b in bandits:
        print("mean estimate:", b.p_estimate)
  
    # print total reward
    print("total reward earned:", rewards.sum())
    print("overall win rate:", rewards.sum() / NUM_TRIALS)
    print("num times selected each bandit:", [b.N for b in bandits])
  
    # plot the results
    cumulative_rewards = np.cumsum(rewards)
    win_rates = cumulative_rewards / (np.arange(NUM_TRIALS) + 1)
    plt.ylim([0, 1])
    plt.plot(win_rates)
    plt.plot(np.ones(NUM_TRIALS)*np.max(BANDIT_PROBABILITIES))
    plt.show()

if __name__ == "__main__":
    experiment()
# Out:
# mean estimate: 0.7000000000000002
# mean estimate: 0.7000000000000001
# mean estimate: 0.7540901334939265
# total reward earned: 7526.0
# overall win rate: 0.7526
# num times selected each bandit: [10, 30, 9963]

# %% [markdown]
# #### 3.0 comparing epsilons

# %%
# Show random distribution
import numpy as np
import matplotlib.pyplot as plt 
i = []
for j in range(0,10000):
    i.append(np.random.randn())
i.sort()
plt.hist(i, bins=100);

# %% [markdown]
# #### 2.0 (see .py file)

# %% [markdown]
# #### 1.0 greedy and epsilon greedy (wrong)

# %%
import random

# Define probabilistic game outcome
def win_lose(a, b):
    x = random.randint(a,b)
    if x > 50:
        y = 1
    else:
        y = 0
    return y

def play_A():
    print("playing A")
    y = win_lose(1,100)
    print("y: ", y)
    return y

def play_B():
    print("playing B")
    y = win_lose(1,60)
    print("y: ", y)
    return y

# %%
# Greedy
A_wins = A_plays = B_plays = B_wins = 0
A_win_rate = B_win_rate = 0.1
epochs = 100

for i in range(0,epochs):    
    print("i:", i)
    if (A_win_rate == 0) & (B_win_rate == 0):
        y = play_A()
        A_plays += 1
        A_wins += y
        A_win_rate = A_wins/A_plays
    elif A_win_rate >= B_win_rate:
        y = play_A()
        A_plays += 1
        A_wins += y
        A_win_rate = A_wins/A_plays
    else:
        y = play_B()
        B_plays += 1
        B_wins += y
        B_win_rate = B_wins/B_plays
    print("A_win_rate: ", A_win_rate)
    print("B_win_rate: ", B_win_rate)
    print("A_plays: ", A_plays)
    print("B_plays: ", B_plays)
    print("\n")
# Out:
# i: 0
# playing A
# y:  1
# A_win_rate:  1.0
# B_win_rate:  0.1
# A_plays:  1
# B_plays:  0
#
#
# i: 1
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.1
# A_plays:  2
# B_plays:  0
#
#
# i: 2
# playing A
# y:  1
# A_win_rate:  0.6666666666666666
# B_win_rate:  0.1
# A_plays:  3
# B_plays:  0
#
#
# i: 3
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.1
# A_plays:  4
# B_plays:  0
#
#
# i: 4
# playing A
# y:  1
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  5
# B_plays:  0
#
#
# i: 5
# playing A
# y:  1
# A_win_rate:  0.6666666666666666
# B_win_rate:  0.1
# A_plays:  6
# B_plays:  0
#
#
# i: 6
# playing A
# y:  1
# A_win_rate:  0.7142857142857143
# B_win_rate:  0.1
# A_plays:  7
# B_plays:  0
#
#
# i: 7
# playing A
# y:  1
# A_win_rate:  0.75
# B_win_rate:  0.1
# A_plays:  8
# B_plays:  0
#
#
# i: 8
# playing A
# y:  0
# A_win_rate:  0.6666666666666666
# B_win_rate:  0.1
# A_plays:  9
# B_plays:  0
#
#
# i: 9
# playing A
# y:  1
# A_win_rate:  0.7
# B_win_rate:  0.1
# A_plays:  10
# B_plays:  0
#
#
# i: 10
# playing A
# y:  0
# A_win_rate:  0.6363636363636364
# B_win_rate:  0.1
# A_plays:  11
# B_plays:  0
#
#
# i: 11
# playing A
# y:  1
# A_win_rate:  0.6666666666666666
# B_win_rate:  0.1
# A_plays:  12
# B_plays:  0
#
#
# i: 12
# playing A
# y:  0
# A_win_rate:  0.6153846153846154
# B_win_rate:  0.1
# A_plays:  13
# B_plays:  0
#
#
# i: 13
# playing A
# y:  0
# A_win_rate:  0.5714285714285714
# B_win_rate:  0.1
# A_plays:  14
# B_plays:  0
#
#
# i: 14
# playing A
# y:  1
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  15
# B_plays:  0
#
#
# i: 15
# playing A
# y:  1
# A_win_rate:  0.625
# B_win_rate:  0.1
# A_plays:  16
# B_plays:  0
#
#
# i: 16
# playing A
# y:  0
# A_win_rate:  0.5882352941176471
# B_win_rate:  0.1
# A_plays:  17
# B_plays:  0
#
#
# i: 17
# playing A
# y:  1
# A_win_rate:  0.6111111111111112
# B_win_rate:  0.1
# A_plays:  18
# B_plays:  0
#
#
# i: 18
# playing A
# y:  1
# A_win_rate:  0.631578947368421
# B_win_rate:  0.1
# A_plays:  19
# B_plays:  0
#
#
# i: 19
# playing A
# y:  0
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  20
# B_plays:  0
#
#
# i: 20
# playing A
# y:  1
# A_win_rate:  0.6190476190476191
# B_win_rate:  0.1
# A_plays:  21
# B_plays:  0
#
#
# i: 21
# playing A
# y:  0
# A_win_rate:  0.5909090909090909
# B_win_rate:  0.1
# A_plays:  22
# B_plays:  0
#
#
# i: 22
# playing A
# y:  1
# A_win_rate:  0.6086956521739131
# B_win_rate:  0.1
# A_plays:  23
# B_plays:  0
#
#
# i: 23
# playing A
# y:  0
# A_win_rate:  0.5833333333333334
# B_win_rate:  0.1
# A_plays:  24
# B_plays:  0
#
#
# i: 24
# playing A
# y:  1
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  25
# B_plays:  0
#
#
# i: 25
# playing A
# y:  0
# A_win_rate:  0.5769230769230769
# B_win_rate:  0.1
# A_plays:  26
# B_plays:  0
#
#
# i: 26
# playing A
# y:  1
# A_win_rate:  0.5925925925925926
# B_win_rate:  0.1
# A_plays:  27
# B_plays:  0
#
#
# i: 27
# playing A
# y:  1
# A_win_rate:  0.6071428571428571
# B_win_rate:  0.1
# A_plays:  28
# B_plays:  0
#
#
# i: 28
# playing A
# y:  0
# A_win_rate:  0.5862068965517241
# B_win_rate:  0.1
# A_plays:  29
# B_plays:  0
#
#
# i: 29
# playing A
# y:  0
# A_win_rate:  0.5666666666666667
# B_win_rate:  0.1
# A_plays:  30
# B_plays:  0
#
#
# i: 30
# playing A
# y:  1
# A_win_rate:  0.5806451612903226
# B_win_rate:  0.1
# A_plays:  31
# B_plays:  0
#
#
# i: 31
# playing A
# y:  1
# A_win_rate:  0.59375
# B_win_rate:  0.1
# A_plays:  32
# B_plays:  0
#
#
# i: 32
# playing A
# y:  1
# A_win_rate:  0.6060606060606061
# B_win_rate:  0.1
# A_plays:  33
# B_plays:  0
#
#
# i: 33
# playing A
# y:  1
# A_win_rate:  0.6176470588235294
# B_win_rate:  0.1
# A_plays:  34
# B_plays:  0
#
#
# i: 34
# playing A
# y:  1
# A_win_rate:  0.6285714285714286
# B_win_rate:  0.1
# A_plays:  35
# B_plays:  0
#
#
# i: 35
# playing A
# y:  0
# A_win_rate:  0.6111111111111112
# B_win_rate:  0.1
# A_plays:  36
# B_plays:  0
#
#
# i: 36
# playing A
# y:  0
# A_win_rate:  0.5945945945945946
# B_win_rate:  0.1
# A_plays:  37
# B_plays:  0
#
#
# i: 37
# playing A
# y:  0
# A_win_rate:  0.5789473684210527
# B_win_rate:  0.1
# A_plays:  38
# B_plays:  0
#
#
# i: 38
# playing A
# y:  1
# A_win_rate:  0.5897435897435898
# B_win_rate:  0.1
# A_plays:  39
# B_plays:  0
#
#
# i: 39
# playing A
# y:  1
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  40
# B_plays:  0
#
#
# i: 40
# playing A
# y:  0
# A_win_rate:  0.5853658536585366
# B_win_rate:  0.1
# A_plays:  41
# B_plays:  0
#
#
# i: 41
# playing A
# y:  0
# A_win_rate:  0.5714285714285714
# B_win_rate:  0.1
# A_plays:  42
# B_plays:  0
#
#
# i: 42
# playing A
# y:  0
# A_win_rate:  0.5581395348837209
# B_win_rate:  0.1
# A_plays:  43
# B_plays:  0
#
#
# i: 43
# playing A
# y:  1
# A_win_rate:  0.5681818181818182
# B_win_rate:  0.1
# A_plays:  44
# B_plays:  0
#
#
# i: 44
# playing A
# y:  0
# A_win_rate:  0.5555555555555556
# B_win_rate:  0.1
# A_plays:  45
# B_plays:  0
#
#
# i: 45
# playing A
# y:  1
# A_win_rate:  0.5652173913043478
# B_win_rate:  0.1
# A_plays:  46
# B_plays:  0
#
#
# i: 46
# playing A
# y:  0
# A_win_rate:  0.5531914893617021
# B_win_rate:  0.1
# A_plays:  47
# B_plays:  0
#
#
# i: 47
# playing A
# y:  1
# A_win_rate:  0.5625
# B_win_rate:  0.1
# A_plays:  48
# B_plays:  0
#
#
# i: 48
# playing A
# y:  0
# A_win_rate:  0.5510204081632653
# B_win_rate:  0.1
# A_plays:  49
# B_plays:  0
#
#
# i: 49
# playing A
# y:  1
# A_win_rate:  0.56
# B_win_rate:  0.1
# A_plays:  50
# B_plays:  0
#
#
# i: 50
# playing A
# y:  1
# A_win_rate:  0.5686274509803921
# B_win_rate:  0.1
# A_plays:  51
# B_plays:  0
#
#
# i: 51
# playing A
# y:  0
# A_win_rate:  0.5576923076923077
# B_win_rate:  0.1
# A_plays:  52
# B_plays:  0
#
#
# i: 52
# playing A
# y:  0
# A_win_rate:  0.5471698113207547
# B_win_rate:  0.1
# A_plays:  53
# B_plays:  0
#
#
# i: 53
# playing A
# y:  1
# A_win_rate:  0.5555555555555556
# B_win_rate:  0.1
# A_plays:  54
# B_plays:  0
#
#
# i: 54
# playing A
# y:  0
# A_win_rate:  0.5454545454545454
# B_win_rate:  0.1
# A_plays:  55
# B_plays:  0
#
#
# i: 55
# playing A
# y:  0
# A_win_rate:  0.5357142857142857
# B_win_rate:  0.1
# A_plays:  56
# B_plays:  0
#
#
# i: 56
# playing A
# y:  0
# A_win_rate:  0.5263157894736842
# B_win_rate:  0.1
# A_plays:  57
# B_plays:  0
#
#
# i: 57
# playing A
# y:  1
# A_win_rate:  0.5344827586206896
# B_win_rate:  0.1
# A_plays:  58
# B_plays:  0
#
#
# i: 58
# playing A
# y:  1
# A_win_rate:  0.5423728813559322
# B_win_rate:  0.1
# A_plays:  59
# B_plays:  0
#
#
# i: 59
# playing A
# y:  1
# A_win_rate:  0.55
# B_win_rate:  0.1
# A_plays:  60
# B_plays:  0
#
#
# i: 60
# playing A
# y:  0
# A_win_rate:  0.5409836065573771
# B_win_rate:  0.1
# A_plays:  61
# B_plays:  0
#
#
# i: 61
# playing A
# y:  0
# A_win_rate:  0.532258064516129
# B_win_rate:  0.1
# A_plays:  62
# B_plays:  0
#
#
# i: 62
# playing A
# y:  1
# A_win_rate:  0.5396825396825397
# B_win_rate:  0.1
# A_plays:  63
# B_plays:  0
#
#
# i: 63
# playing A
# y:  1
# A_win_rate:  0.546875
# B_win_rate:  0.1
# A_plays:  64
# B_plays:  0
#
#
# i: 64
# playing A
# y:  1
# A_win_rate:  0.5538461538461539
# B_win_rate:  0.1
# A_plays:  65
# B_plays:  0
#
#
# i: 65
# playing A
# y:  1
# A_win_rate:  0.5606060606060606
# B_win_rate:  0.1
# A_plays:  66
# B_plays:  0
#
#
# i: 66
# playing A
# y:  0
# A_win_rate:  0.5522388059701493
# B_win_rate:  0.1
# A_plays:  67
# B_plays:  0
#
#
# i: 67
# playing A
# y:  1
# A_win_rate:  0.5588235294117647
# B_win_rate:  0.1
# A_plays:  68
# B_plays:  0
#
#
# i: 68
# playing A
# y:  1
# A_win_rate:  0.5652173913043478
# B_win_rate:  0.1
# A_plays:  69
# B_plays:  0
#
#
# i: 69
# playing A
# y:  1
# A_win_rate:  0.5714285714285714
# B_win_rate:  0.1
# A_plays:  70
# B_plays:  0
#
#
# i: 70
# playing A
# y:  0
# A_win_rate:  0.5633802816901409
# B_win_rate:  0.1
# A_plays:  71
# B_plays:  0
#
#
# i: 71
# playing A
# y:  1
# A_win_rate:  0.5694444444444444
# B_win_rate:  0.1
# A_plays:  72
# B_plays:  0
#
#
# i: 72
# playing A
# y:  1
# A_win_rate:  0.5753424657534246
# B_win_rate:  0.1
# A_plays:  73
# B_plays:  0
#
#
# i: 73
# playing A
# y:  1
# A_win_rate:  0.581081081081081
# B_win_rate:  0.1
# A_plays:  74
# B_plays:  0
#
#
# i: 74
# playing A
# y:  0
# A_win_rate:  0.5733333333333334
# B_win_rate:  0.1
# A_plays:  75
# B_plays:  0
#
#
# i: 75
# playing A
# y:  1
# A_win_rate:  0.5789473684210527
# B_win_rate:  0.1
# A_plays:  76
# B_plays:  0
#
#
# i: 76
# playing A
# y:  0
# A_win_rate:  0.5714285714285714
# B_win_rate:  0.1
# A_plays:  77
# B_plays:  0
#
#
# i: 77
# playing A
# y:  1
# A_win_rate:  0.5769230769230769
# B_win_rate:  0.1
# A_plays:  78
# B_plays:  0
#
#
# i: 78
# playing A
# y:  1
# A_win_rate:  0.5822784810126582
# B_win_rate:  0.1
# A_plays:  79
# B_plays:  0
#
#
# i: 79
# playing A
# y:  1
# A_win_rate:  0.5875
# B_win_rate:  0.1
# A_plays:  80
# B_plays:  0
#
#
# i: 80
# playing A
# y:  1
# A_win_rate:  0.5925925925925926
# B_win_rate:  0.1
# A_plays:  81
# B_plays:  0
#
#
# i: 81
# playing A
# y:  1
# A_win_rate:  0.5975609756097561
# B_win_rate:  0.1
# A_plays:  82
# B_plays:  0
#
#
# i: 82
# playing A
# y:  1
# A_win_rate:  0.6024096385542169
# B_win_rate:  0.1
# A_plays:  83
# B_plays:  0
#
#
# i: 83
# playing A
# y:  0
# A_win_rate:  0.5952380952380952
# B_win_rate:  0.1
# A_plays:  84
# B_plays:  0
#
#
# i: 84
# playing A
# y:  1
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  85
# B_plays:  0
#
#
# i: 85
# playing A
# y:  0
# A_win_rate:  0.5930232558139535
# B_win_rate:  0.1
# A_plays:  86
# B_plays:  0
#
#
# i: 86
# playing A
# y:  1
# A_win_rate:  0.5977011494252874
# B_win_rate:  0.1
# A_plays:  87
# B_plays:  0
#
#
# i: 87
# playing A
# y:  1
# A_win_rate:  0.6022727272727273
# B_win_rate:  0.1
# A_plays:  88
# B_plays:  0
#
#
# i: 88
# playing A
# y:  1
# A_win_rate:  0.6067415730337079
# B_win_rate:  0.1
# A_plays:  89
# B_plays:  0
#
#
# i: 89
# playing A
# y:  0
# A_win_rate:  0.6
# B_win_rate:  0.1
# A_plays:  90
# B_plays:  0
#
#
# i: 90
# playing A
# y:  1
# A_win_rate:  0.6043956043956044
# B_win_rate:  0.1
# A_plays:  91
# B_plays:  0
#
#
# i: 91
# playing A
# y:  1
# A_win_rate:  0.6086956521739131
# B_win_rate:  0.1
# A_plays:  92
# B_plays:  0
#
#
# i: 92
# playing A
# y:  1
# A_win_rate:  0.6129032258064516
# B_win_rate:  0.1
# A_plays:  93
# B_plays:  0
#
#
# i: 93
# playing A
# y:  1
# A_win_rate:  0.6170212765957447
# B_win_rate:  0.1
# A_plays:  94
# B_plays:  0
#
#
# i: 94
# playing A
# y:  0
# A_win_rate:  0.6105263157894737
# B_win_rate:  0.1
# A_plays:  95
# B_plays:  0
#
#
# i: 95
# playing A
# y:  1
# A_win_rate:  0.6145833333333334
# B_win_rate:  0.1
# A_plays:  96
# B_plays:  0
#
#
# i: 96
# playing A
# y:  1
# A_win_rate:  0.6185567010309279
# B_win_rate:  0.1
# A_plays:  97
# B_plays:  0
#
#
# i: 97
# playing A
# y:  0
# A_win_rate:  0.6122448979591837
# B_win_rate:  0.1
# A_plays:  98
# B_plays:  0
#
#
# i: 98
# playing A
# y:  0
# A_win_rate:  0.6060606060606061
# B_win_rate:  0.1
# A_plays:  99
# B_plays:  0
#
#
# i: 99
# playing A
# y:  1
# A_win_rate:  0.61
# B_win_rate:  0.1
# A_plays:  100
# B_plays:  0

# %%
# Epsilon Greedy
A_wins = A_plays = B_plays = B_wins = 0
A_win_rate = B_win_rate = 0.1
epochs = 100
epsilon = 0.1
            
for i in range(0,epochs):
    print("i:", i)
    # Choose whether to choose a random bandit
    p = random.randint(0,100)/100
    if p < epsilon:
        print(f"p = {p}, epsilon = {epsilon}")
        s = random.randint(0,100)/100
        if s > 0.5:
            print("picking bandit: A")
            y = play_A()
            A_plays += 1
            A_wins += y
            A_win_rate = A_wins/A_plays
        else:
            print("picking bandit: B")
            y = play_B()
            B_plays += 1
            B_wins += y
            B_win_rate = B_wins/B_plays
        print("A_win_rate: ", A_win_rate)
        print("B_win_rate: ", B_win_rate)
        print("A_plays: ", A_plays)
        print("B_plays: ", B_plays)
        print("\n")

    else:        
        if (A_win_rate == 0) & (B_win_rate == 0):
            y = play_A()
            A_plays += 1
            A_wins += y
            A_win_rate = A_wins/A_plays
        elif A_win_rate >= B_win_rate:
            y = play_A()
            A_plays += 1
            A_wins += y
            A_win_rate = A_wins/A_plays
        else:
            y = play_B()
            B_plays += 1
            B_wins += y
            B_win_rate = B_wins/B_plays
        print("A_win_rate: ", A_win_rate)
        print("B_win_rate: ", B_win_rate)
        print("A_plays: ", A_plays)
        print("B_plays: ", B_plays)
        print("\n")
# Out:
# i: 0
# playing A
# y:  1
# A_win_rate:  1.0
# B_win_rate:  0.1
# A_plays:  1
# B_plays:  0
#
#
# i: 1
# playing A
# y:  1
# A_win_rate:  1.0
# B_win_rate:  0.1
# A_plays:  2
# B_plays:  0
#
#
# i: 2
# playing A
# y:  0
# A_win_rate:  0.6666666666666666
# B_win_rate:  0.1
# A_plays:  3
# B_plays:  0
#
#
# i: 3
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.1
# A_plays:  4
# B_plays:  0
#
#
# i: 4
# playing A
# y:  0
# A_win_rate:  0.4
# B_win_rate:  0.1
# A_plays:  5
# B_plays:  0
#
#
# i: 5
# playing A
# y:  0
# A_win_rate:  0.3333333333333333
# B_win_rate:  0.1
# A_plays:  6
# B_plays:  0
#
#
# i: 6
# playing A
# y:  0
# A_win_rate:  0.2857142857142857
# B_win_rate:  0.1
# A_plays:  7
# B_plays:  0
#
#
# i: 7
# playing A
# y:  0
# A_win_rate:  0.25
# B_win_rate:  0.1
# A_plays:  8
# B_plays:  0
#
#
# i: 8
# playing A
# y:  1
# A_win_rate:  0.3333333333333333
# B_win_rate:  0.1
# A_plays:  9
# B_plays:  0
#
#
# i: 9
# playing A
# y:  1
# A_win_rate:  0.4
# B_win_rate:  0.1
# A_plays:  10
# B_plays:  0
#
#
# i: 10
# playing A
# y:  0
# A_win_rate:  0.36363636363636365
# B_win_rate:  0.1
# A_plays:  11
# B_plays:  0
#
#
# i: 11
# playing A
# y:  1
# A_win_rate:  0.4166666666666667
# B_win_rate:  0.1
# A_plays:  12
# B_plays:  0
#
#
# i: 12
# playing A
# y:  1
# A_win_rate:  0.46153846153846156
# B_win_rate:  0.1
# A_plays:  13
# B_plays:  0
#
#
# i: 13
# p = 0.02, epsilon = 0.1
# picking bandit: B
# playing B
# y:  0
# A_win_rate:  0.46153846153846156
# B_win_rate:  0.0
# A_plays:  13
# B_plays:  1
#
#
# i: 14
# playing A
# y:  0
# A_win_rate:  0.42857142857142855
# B_win_rate:  0.0
# A_plays:  14
# B_plays:  1
#
#
# i: 15
# playing A
# y:  1
# A_win_rate:  0.4666666666666667
# B_win_rate:  0.0
# A_plays:  15
# B_plays:  1
#
#
# i: 16
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  16
# B_plays:  1
#
#
# i: 17
# playing A
# y:  0
# A_win_rate:  0.47058823529411764
# B_win_rate:  0.0
# A_plays:  17
# B_plays:  1
#
#
# i: 18
# playing A
# y:  0
# A_win_rate:  0.4444444444444444
# B_win_rate:  0.0
# A_plays:  18
# B_plays:  1
#
#
# i: 19
# playing A
# y:  1
# A_win_rate:  0.47368421052631576
# B_win_rate:  0.0
# A_plays:  19
# B_plays:  1
#
#
# i: 20
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  20
# B_plays:  1
#
#
# i: 21
# playing A
# y:  0
# A_win_rate:  0.47619047619047616
# B_win_rate:  0.0
# A_plays:  21
# B_plays:  1
#
#
# i: 22
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  22
# B_plays:  1
#
#
# i: 23
# playing A
# y:  1
# A_win_rate:  0.5217391304347826
# B_win_rate:  0.0
# A_plays:  23
# B_plays:  1
#
#
# i: 24
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  24
# B_plays:  1
#
#
# i: 25
# playing A
# y:  1
# A_win_rate:  0.52
# B_win_rate:  0.0
# A_plays:  25
# B_plays:  1
#
#
# i: 26
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  26
# B_plays:  1
#
#
# i: 27
# playing A
# y:  0
# A_win_rate:  0.48148148148148145
# B_win_rate:  0.0
# A_plays:  27
# B_plays:  1
#
#
# i: 28
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  28
# B_plays:  1
#
#
# i: 29
# playing A
# y:  0
# A_win_rate:  0.4827586206896552
# B_win_rate:  0.0
# A_plays:  29
# B_plays:  1
#
#
# i: 30
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  30
# B_plays:  1
#
#
# i: 31
# playing A
# y:  1
# A_win_rate:  0.5161290322580645
# B_win_rate:  0.0
# A_plays:  31
# B_plays:  1
#
#
# i: 32
# p = 0.09, epsilon = 0.1
# picking bandit: B
# playing B
# y:  0
# A_win_rate:  0.5161290322580645
# B_win_rate:  0.0
# A_plays:  31
# B_plays:  2
#
#
# i: 33
# playing A
# y:  1
# A_win_rate:  0.53125
# B_win_rate:  0.0
# A_plays:  32
# B_plays:  2
#
#
# i: 34
# playing A
# y:  1
# A_win_rate:  0.5454545454545454
# B_win_rate:  0.0
# A_plays:  33
# B_plays:  2
#
#
# i: 35
# playing A
# y:  0
# A_win_rate:  0.5294117647058824
# B_win_rate:  0.0
# A_plays:  34
# B_plays:  2
#
#
# i: 36
# playing A
# y:  1
# A_win_rate:  0.5428571428571428
# B_win_rate:  0.0
# A_plays:  35
# B_plays:  2
#
#
# i: 37
# playing A
# y:  0
# A_win_rate:  0.5277777777777778
# B_win_rate:  0.0
# A_plays:  36
# B_plays:  2
#
#
# i: 38
# playing A
# y:  0
# A_win_rate:  0.5135135135135135
# B_win_rate:  0.0
# A_plays:  37
# B_plays:  2
#
#
# i: 39
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  38
# B_plays:  2
#
#
# i: 40
# playing A
# y:  0
# A_win_rate:  0.48717948717948717
# B_win_rate:  0.0
# A_plays:  39
# B_plays:  2
#
#
# i: 41
# playing A
# y:  0
# A_win_rate:  0.475
# B_win_rate:  0.0
# A_plays:  40
# B_plays:  2
#
#
# i: 42
# playing A
# y:  1
# A_win_rate:  0.4878048780487805
# B_win_rate:  0.0
# A_plays:  41
# B_plays:  2
#
#
# i: 43
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  42
# B_plays:  2
#
#
# i: 44
# playing A
# y:  0
# A_win_rate:  0.4883720930232558
# B_win_rate:  0.0
# A_plays:  43
# B_plays:  2
#
#
# i: 45
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  44
# B_plays:  2
#
#
# i: 46
# playing A
# y:  1
# A_win_rate:  0.5111111111111111
# B_win_rate:  0.0
# A_plays:  45
# B_plays:  2
#
#
# i: 47
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  46
# B_plays:  2
#
#
# i: 48
# playing A
# y:  1
# A_win_rate:  0.5106382978723404
# B_win_rate:  0.0
# A_plays:  47
# B_plays:  2
#
#
# i: 49
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  48
# B_plays:  2
#
#
# i: 50
# playing A
# y:  1
# A_win_rate:  0.5102040816326531
# B_win_rate:  0.0
# A_plays:  49
# B_plays:  2
#
#
# i: 51
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  50
# B_plays:  2
#
#
# i: 52
# playing A
# y:  0
# A_win_rate:  0.49019607843137253
# B_win_rate:  0.0
# A_plays:  51
# B_plays:  2
#
#
# i: 53
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  52
# B_plays:  2
#
#
# i: 54
# playing A
# y:  0
# A_win_rate:  0.49056603773584906
# B_win_rate:  0.0
# A_plays:  53
# B_plays:  2
#
#
# i: 55
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  54
# B_plays:  2
#
#
# i: 56
# playing A
# y:  0
# A_win_rate:  0.4909090909090909
# B_win_rate:  0.0
# A_plays:  55
# B_plays:  2
#
#
# i: 57
# playing A
# y:  1
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  56
# B_plays:  2
#
#
# i: 58
# playing A
# y:  1
# A_win_rate:  0.5087719298245614
# B_win_rate:  0.0
# A_plays:  57
# B_plays:  2
#
#
# i: 59
# playing A
# y:  1
# A_win_rate:  0.5172413793103449
# B_win_rate:  0.0
# A_plays:  58
# B_plays:  2
#
#
# i: 60
# playing A
# y:  0
# A_win_rate:  0.5084745762711864
# B_win_rate:  0.0
# A_plays:  59
# B_plays:  2
#
#
# i: 61
# playing A
# y:  1
# A_win_rate:  0.5166666666666667
# B_win_rate:  0.0
# A_plays:  60
# B_plays:  2
#
#
# i: 62
# playing A
# y:  1
# A_win_rate:  0.5245901639344263
# B_win_rate:  0.0
# A_plays:  61
# B_plays:  2
#
#
# i: 63
# playing A
# y:  0
# A_win_rate:  0.5161290322580645
# B_win_rate:  0.0
# A_plays:  62
# B_plays:  2
#
#
# i: 64
# playing A
# y:  1
# A_win_rate:  0.5238095238095238
# B_win_rate:  0.0
# A_plays:  63
# B_plays:  2
#
#
# i: 65
# playing A
# y:  0
# A_win_rate:  0.515625
# B_win_rate:  0.0
# A_plays:  64
# B_plays:  2
#
#
# i: 66
# playing A
# y:  0
# A_win_rate:  0.5076923076923077
# B_win_rate:  0.0
# A_plays:  65
# B_plays:  2
#
#
# i: 67
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  66
# B_plays:  2
#
#
# i: 68
# playing A
# y:  1
# A_win_rate:  0.5074626865671642
# B_win_rate:  0.0
# A_plays:  67
# B_plays:  2
#
#
# i: 69
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  68
# B_plays:  2
#
#
# i: 70
# playing A
# y:  1
# A_win_rate:  0.5072463768115942
# B_win_rate:  0.0
# A_plays:  69
# B_plays:  2
#
#
# i: 71
# playing A
# y:  0
# A_win_rate:  0.5
# B_win_rate:  0.0
# A_plays:  70
# B_plays:  2
#
#
# i: 72
# playing A
# y:  0
# A_win_rate:  0.49295774647887325
# B_win_rate:  0.0
# A_plays:  71
# B_plays:  2
#
#
# i: 73
# p = 0.0, epsilon = 0.1
# picking bandit: A
# playing A
# y:  0
# A_win_rate:  0.4861111111111111
# B_win_rate:  0.0
# A_plays:  72
# B_plays:  2
#
#
# i: 74
# playing A
# y:  0
# A_win_rate:  0.4794520547945205
# B_win_rate:  0.0
# A_plays:  73
# B_plays:  2
#
#
# i: 75
# playing A
# y:  0
# A_win_rate:  0.47297297297297297
# B_win_rate:  0.0
# A_plays:  74
# B_plays:  2
#
#
# i: 76
# playing A
# y:  1
# A_win_rate:  0.48
# B_win_rate:  0.0
# A_plays:  75
# B_plays:  2
#
#
# i: 77
# playing A
# y:  0
# A_win_rate:  0.47368421052631576
# B_win_rate:  0.0
# A_plays:  76
# B_plays:  2
#
#
# i: 78
# p = 0.06, epsilon = 0.1
# picking bandit: B
# playing B
# y:  0
# A_win_rate:  0.47368421052631576
# B_win_rate:  0.0
# A_plays:  76
# B_plays:  3
#
#
# i: 79
# playing A
# y:  1
# A_win_rate:  0.4805194805194805
# B_win_rate:  0.0
# A_plays:  77
# B_plays:  3
#
#
# i: 80
# playing A
# y:  1
# A_win_rate:  0.48717948717948717
# B_win_rate:  0.0
# A_plays:  78
# B_plays:  3
#
#
# i: 81
# p = 0.06, epsilon = 0.1
# picking bandit: A
# playing A
# y:  1
# A_win_rate:  0.4936708860759494
# B_win_rate:  0.0
# A_plays:  79
# B_plays:  3
#
#
# i: 82
# playing A
# y:  0
# A_win_rate:  0.4875
# B_win_rate:  0.0
# A_plays:  80
# B_plays:  3
#
#
# i: 83
# playing A
# y:  0
# A_win_rate:  0.48148148148148145
# B_win_rate:  0.0
# A_plays:  81
# B_plays:  3
#
#
# i: 84
# playing A
# y:  1
# A_win_rate:  0.4878048780487805
# B_win_rate:  0.0
# A_plays:  82
# B_plays:  3
#
#
# i: 85
# playing A
# y:  0
# A_win_rate:  0.4819277108433735
# B_win_rate:  0.0
# A_plays:  83
# B_plays:  3
#
#
# i: 86
# playing A
# y:  0
# A_win_rate:  0.47619047619047616
# B_win_rate:  0.0
# A_plays:  84
# B_plays:  3
#
#
# i: 87
# playing A
# y:  0
# A_win_rate:  0.47058823529411764
# B_win_rate:  0.0
# A_plays:  85
# B_plays:  3
#
#
# i: 88
# playing A
# y:  0
# A_win_rate:  0.46511627906976744
# B_win_rate:  0.0
# A_plays:  86
# B_plays:  3
#
#
# i: 89
# playing A
# y:  1
# A_win_rate:  0.47126436781609193
# B_win_rate:  0.0
# A_plays:  87
# B_plays:  3
#
#
# i: 90
# playing A
# y:  0
# A_win_rate:  0.4659090909090909
# B_win_rate:  0.0
# A_plays:  88
# B_plays:  3
#
#
# i: 91
# playing A
# y:  1
# A_win_rate:  0.47191011235955055
# B_win_rate:  0.0
# A_plays:  89
# B_plays:  3
#
#
# i: 92
# playing A
# y:  0
# A_win_rate:  0.4666666666666667
# B_win_rate:  0.0
# A_plays:  90
# B_plays:  3
#
#
# i: 93
# playing A
# y:  1
# A_win_rate:  0.4725274725274725
# B_win_rate:  0.0
# A_plays:  91
# B_plays:  3
#
#
# i: 94
# playing A
# y:  1
# A_win_rate:  0.4782608695652174
# B_win_rate:  0.0
# A_plays:  92
# B_plays:  3
#
#
# i: 95
# playing A
# y:  0
# A_win_rate:  0.4731182795698925
# B_win_rate:  0.0
# A_plays:  93
# B_plays:  3
#
#
# i: 96
# playing A
# y:  1
# A_win_rate:  0.4787234042553192
# B_win_rate:  0.0
# A_plays:  94
# B_plays:  3
#
#
# i: 97
# playing A
# y:  1
# A_win_rate:  0.4842105263157895
# B_win_rate:  0.0
# A_plays:  95
# B_plays:  3
#
#
# i: 98
# playing A
# y:  1
# A_win_rate:  0.4895833333333333
# B_win_rate:  0.0
# A_plays:  96
# B_plays:  3
#
#
# i: 99
# playing A
# y:  1
# A_win_rate:  0.4948453608247423
# B_win_rate:  0.0
# A_plays:  97
# B_plays:  3
